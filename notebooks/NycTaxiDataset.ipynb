# %% [markdown]
# ## Description
#
# We follow the works on distributed GPs and on stochastic GPs which run benchmarks on a huge dataset of taxi rides in the city of New York.
#
# The dataset is not well standardized so some preprocessing steps are necessary. Useful links are:
#  - https://github.com/toddwschneider/nyc-taxi-data -- for data download scripts and preprocessing help
#  - ? for data description
#  - ? first usage? of the dataset
#
# The goal of this benchmark is to predict the duration of a trip, given 9 features:
#  1. time of the day
#  2. day of the week
#  3. day of the month
#  4. month
#  5. pick-up latitude
#  6. pick-up longitude
#  7. drop-off latitude
#  8. drop-off longitude
#  9. travel distance
#
# While the data is available from 2009 to today, we will only use the trips from January 2009 to December 2015 in order to provide a fair comparison with other methods.
#
# Furthermore, we must exclude trips that are outside the NYC area, and those that are more than 5 hours long.
#
# If all goes well we should have the following aggregate statistics for our target variable:
#  - average traveling time is 764 seconds
#  - standard derivation is 576 seconds.

# %% [markdown]
# After the import into postgresql we have table `trips` with the following columns:
# ```
# id
# pickup_datetime
# dropoff_datetime
# pickup_longitude
# pickup_latitude
# dropoff_longitude
# dropoff_latitude
# trip_distance
# pickup_nyct2010_gid
# dropoff_nyct2010_gid
# ```

# %% [markdown]
# Since we create the git fields by intersecting with a NYC map, the trips where gid is null are assumed to be outside of nyc.
#
# We can count approximately 32M such points
#
# ```sql
# SELECT COUNT(*) FROM trips WHERE (pickup_nyct2010_gid is null) OR (dropoff_nyct2010_gid is null);
# ```
# ```
# 32'771'382
# ```

# %% [markdown]
# Further, there are a bunch of outliers on the trip duration column: trips with negative duration or trips with extremely long duration.
# We exclude all trips more than 5 hours (3600*5=18000) long, and all those with negative duration.
#
# ```sql
# SELECT COUNT(*) FROM trips WHERE
#     EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime)
#     NOT BETWEEN 0 AND 18000;
# ```
# ```
# 481135
# ```

# %% [markdown]
# Excluding both kinds of data-points we get the following summary statistics on the duration column:
# ```sql
# SELECT avg(EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime)),
#        stddev_samp(EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime)),
#        stddev_pop(EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime))
# FROM trips WHERE
# (pickup_nyct2010_gid IS NOT NULL) AND
# (dropoff_nyct2010_gid IS NOT NULL) AND
# (EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime) BETWEEN 0 AND 18000);
# ```
# ```sql
#        avg        |   stddev_samp    |    stddev_pop
# ------------------+------------------+------------------
#  752.520099079508 | 566.116904461205 | 566.116904214329
# ```

# %% [markdown]
# Copy to CSV using pagination
#
# ```sql
# COPY (
#     SELECT
#         id,
#         EXTRACT(EPOCH FROM CAST(pickup_datetime AS time)) as time,
#         EXTRACT(ISODOW FROM pickup_datetime) as dow,
#         EXTRACT(DAY FROM pickup_datetime) as dom,
#         EXTRACT(MONTH FROM pickup_datetime) as month,
#         round(pickup_latitude, 6),
#         round(pickup_longitude, 6),
#         round(dropoff_latitude, 6),
#         round(dropoff_longitude, 6),
#         round(trip_distance, 3),
#         EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime) as duration
#     FROM trips WHERE
#         (pickup_nyct2010_gid IS NOT NULL) AND
#         (dropoff_nyct2010_gid IS NOT NULL) AND
#         (EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime) BETWEEN 0 AND 18000) AND
#         (id > 13385191)
#     ORDER BY id ASC
#     LIMIT 10
# ) TO STDOUT
# WITH (FORMAT csv, HEADER true);
# ```

# %%
import psycopg2 
import sys, os, time

# %%
csv_size = 3_000_000
folder = "/data/DATASETS/NYCTAXI/PROCESSED/"
try:
    os.makedirs(folder)
except FileExistsError:
    pass

# %%
def make_copy_sql(from_id, num_rows, out_file):
    return """
    COPY (
        SELECT
            id,
            EXTRACT(EPOCH FROM CAST(pickup_datetime AS time)) as time,
            EXTRACT(ISODOW FROM pickup_datetime) as dow,
            EXTRACT(DAY FROM pickup_datetime) as dom,
            EXTRACT(MONTH FROM pickup_datetime) as month,
            round(pickup_latitude, 6) as pickup_lat,
            round(pickup_longitude, 6) as pickup_lon,
            round(dropoff_latitude, 6) as dropoff_lat,
            round(dropoff_longitude, 6) as dropoff_lon,
            round(trip_distance, 3) as distance,
            EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime) as duration
        FROM trips WHERE 
            (pickup_nyct2010_gid IS NOT NULL) AND 
            (dropoff_nyct2010_gid IS NOT NULL) AND
            (EXTRACT(EPOCH FROM dropoff_datetime - pickup_datetime) BETWEEN 0 AND 18000) AND
            (id > %d)
        ORDER BY id ASC
        LIMIT %d
    ) TO '%s'
    WITH (FORMAT csv, HEADER true);""" % (from_id, num_rows, out_file)

# %%
conn.close()
conn = psycopg2.connect(
    host="localhost", 
    port=5432, 
    database="nyc-taxi-data", 
    user="giacomo")

# %%
index = 0
i = 0
with conn.cursor() as cursor:
    while True:
        t_s = time.time()
        fn = os.path.join(folder, "%d.csv" % (index))
        # Postgres server needs to have permission to create the file
        os.umask(0)
        with open(os.open(fn, os.O_CREAT | os.O_WRONLY, 0o777), 'w') as fh:
            cursor.copy_expert(make_copy_sql(index, csv_size, fn), fh)
        # Read last line of written file to check the new index
        last_line = os.popen('tail -n 1 %s' % (fn)).read()
        if last_line == "":
            break
        index = int(last_line.split(",")[0])
        # Compress the file
        os.popen('gzip -f %s' % (fn))

        i += 1
        print("%d - %.2fs - Retrieved new start ID %d" % (i, time.time() - t_s, index))
# Out:
# 1 - 14.19s - Retrieved new start ID 16500092
# 2 - 15.10s - Retrieved new start ID 19614671
# 3 - 15.00s - Retrieved new start ID 22730160
# 4 - 16.37s - Retrieved new start ID 25844686
# 5 - 16.35s - Retrieved new start ID 28944407
# 6 - 15.43s - Retrieved new start ID 32027576
# 7 - 15.66s - Retrieved new start ID 35110928
# 8 - 15.70s - Retrieved new start ID 38193871
# 9 - 15.40s - Retrieved new start ID 41275223
# 10 - 15.39s - Retrieved new start ID 44347304
# 11 - 16.78s - Retrieved new start ID 47418586
# 12 - 17.12s - Retrieved new start ID 50489809
# 13 - 15.37s - Retrieved new start ID 53561398
# 14 - 16.45s - Retrieved new start ID 56634818
# 15 - 16.23s - Retrieved new start ID 59710543
# 16 - 16.26s - Retrieved new start ID 62785891
# 17 - 15.85s - Retrieved new start ID 65861415
# 18 - 15.57s - Retrieved new start ID 68936775
# 19 - 15.78s - Retrieved new start ID 72013909
# 20 - 16.09s - Retrieved new start ID 75090936
# 21 - 15.21s - Retrieved new start ID 78167466
# 22 - 16.03s - Retrieved new start ID 81244284
# 23 - 15.43s - Retrieved new start ID 84320521
# 24 - 15.89s - Retrieved new start ID 87381840
# 25 - 15.53s - Retrieved new start ID 90443290
# 26 - 15.78s - Retrieved new start ID 93504224
# 27 - 15.92s - Retrieved new start ID 96565501
# 28 - 15.83s - Retrieved new start ID 99626891
# 29 - 16.23s - Retrieved new start ID 102688619
# 30 - 16.46s - Retrieved new start ID 105750702
# 31 - 16.05s - Retrieved new start ID 108811935
# 32 - 16.16s - Retrieved new start ID 111873519
# 33 - 15.44s - Retrieved new start ID 114938154
# 34 - 16.10s - Retrieved new start ID 118004166
# 35 - 16.44s - Retrieved new start ID 121070002
# 36 - 16.40s - Retrieved new start ID 124135478
# 37 - 16.59s - Retrieved new start ID 127202340
# 38 - 15.84s - Retrieved new start ID 130270874
# 39 - 15.58s - Retrieved new start ID 133339529
# 40 - 16.69s - Retrieved new start ID 136407795
# 41 - 16.83s - Retrieved new start ID 139475800
# 42 - 15.81s - Retrieved new start ID 142548202
# 43 - 15.16s - Retrieved new start ID 145620755
# 44 - 15.55s - Retrieved new start ID 148693648
# 45 - 15.78s - Retrieved new start ID 151766239
# 46 - 16.01s - Retrieved new start ID 154838358
# 47 - 15.52s - Retrieved new start ID 157920592
# 48 - 16.60s - Retrieved new start ID 161004334
# 49 - 15.64s - Retrieved new start ID 164087980
# 50 - 16.29s - Retrieved new start ID 167171785
# 51 - 16.09s - Retrieved new start ID 170255350
# 52 - 16.38s - Retrieved new start ID 173335433
# 53 - 15.52s - Retrieved new start ID 176415963
# 54 - 15.92s - Retrieved new start ID 179496509
# 55 - 15.42s - Retrieved new start ID 182577289
# 56 - 15.85s - Retrieved new start ID 185658696
# 57 - 15.34s - Retrieved new start ID 188741177
# 58 - 16.91s - Retrieved new start ID 191823654
# 59 - 16.74s - Retrieved new start ID 194906670
# 60 - 15.61s - Retrieved new start ID 197989435
# 61 - 15.47s - Retrieved new start ID 201072105
# 62 - 16.12s - Retrieved new start ID 204154862
# 63 - 15.53s - Retrieved new start ID 207237975
# 64 - 15.94s - Retrieved new start ID 210320485
# 65 - 15.61s - Retrieved new start ID 213409331
# 66 - 15.36s - Retrieved new start ID 216498298
# 67 - 15.90s - Retrieved new start ID 219587287
# 68 - 17.75s - Retrieved new start ID 222676062
# 69 - 15.90s - Retrieved new start ID 225774499
# 70 - 15.43s - Retrieved new start ID 228874659
# 71 - 16.38s - Retrieved new start ID 231975502
# 133 - 16.92s - Retrieved new start ID 424495727
# 134 - 15.96s - Retrieved new start ID 427590064
# 135 - 15.74s - Retrieved new start ID 430679071
# 136 - 16.49s - Retrieved new start ID 433767535
# 137 - 15.46s - Retrieved new start ID 436856640
# 138 - 16.33s - Retrieved new start ID 439945695
# 139 - 15.93s - Retrieved new start ID 443035983
# 140 - 16.67s - Retrieved new start ID 446132141
# 141 - 16.48s - Retrieved new start ID 449227749
# 142 - 15.32s - Retrieved new start ID 452322840
# 143 - 15.89s - Retrieved new start ID 455418561
# 144 - 16.36s - Retrieved new start ID 458519885
# 145 - 15.98s - Retrieved new start ID 461629493
# 146 - 16.18s - Retrieved new start ID 464739381
# 147 - 15.97s - Retrieved new start ID 467849789
# 148 - 15.89s - Retrieved new start ID 470960813
# 149 - 16.47s - Retrieved new start ID 474077780
# 150 - 15.96s - Retrieved new start ID 477194714
# 151 - 15.79s - Retrieved new start ID 480312075
# 152 - 16.15s - Retrieved new start ID 483430072
# 153 - 15.79s - Retrieved new start ID 486539367
# 154 - 15.99s - Retrieved new start ID 489640517
# 155 - 16.46s - Retrieved new start ID 492741445
# 156 - 15.23s - Retrieved new start ID 495842223
# 157 - 15.44s - Retrieved new start ID 498943605
# 158 - 15.84s - Retrieved new start ID 502042875
# 159 - 16.03s - Retrieved new start ID 505139460
# 160 - 15.37s - Retrieved new start ID 508235866
# 161 - 15.13s - Retrieved new start ID 511332969
# 162 - 15.76s - Retrieved new start ID 514430094
# 163 - 17.12s - Retrieved new start ID 517528214
# 164 - 16.04s - Retrieved new start ID 520626802
# 165 - 16.39s - Retrieved new start ID 523725471
# 166 - 15.43s - Retrieved new start ID 526823762
# 167 - 15.75s - Retrieved new start ID 529921670
# 168 - 15.33s - Retrieved new start ID 533018786
# 169 - 15.44s - Retrieved new start ID 536116450
# 170 - 15.36s - Retrieved new start ID 539213615
# 171 - 17.19s - Retrieved new start ID 542310012
# 172 - 16.18s - Retrieved new start ID 545407332
# 173 - 15.41s - Retrieved new start ID 548506760
# 174 - 15.74s - Retrieved new start ID 551606563
# 175 - 15.53s - Retrieved new start ID 554706500
# 176 - 15.55s - Retrieved new start ID 557806295
# 177 - 15.63s - Retrieved new start ID 560905635
# 178 - 15.71s - Retrieved new start ID 564002866
# 179 - 15.74s - Retrieved new start ID 567101460
# 180 - 15.98s - Retrieved new start ID 570200007
# 181 - 15.31s - Retrieved new start ID 573298160
# 182 - 15.61s - Retrieved new start ID 576396154
# 183 - 15.79s - Retrieved new start ID 579494476
# 184 - 16.90s - Retrieved new start ID 582593228
# 185 - 15.13s - Retrieved new start ID 585692011
# 186 - 15.50s - Retrieved new start ID 588790539
# 187 - 16.10s - Retrieved new start ID 591889373
# 188 - 15.72s - Retrieved new start ID 594994528
# 189 - 15.02s - Retrieved new start ID 598099417
# 190 - 15.40s - Retrieved new start ID 601204396
# 191 - 15.83s - Retrieved new start ID 604309650
# 192 - 15.83s - Retrieved new start ID 607414761
# 193 - 16.25s - Retrieved new start ID 610520601
# 194 - 16.08s - Retrieved new start ID 613626317
# 195 - 16.07s - Retrieved new start ID 616730994
# 196 - 15.31s - Retrieved new start ID 619836262
# 197 - 15.48s - Retrieved new start ID 622941789
# 198 - 16.01s - Retrieved new start ID 626047453
# 199 - 15.77s - Retrieved new start ID 629153169
# 200 - 15.57s - Retrieved new start ID 632259696
# 201 - 16.01s - Retrieved new start ID 635365324
# 202 - 15.68s - Retrieved new start ID 638473572
# 203 - 16.66s - Retrieved new start ID 641583475
# 204 - 16.55s - Retrieved new start ID 644693261
# 205 - 15.71s - Retrieved new start ID 647802973
# 206 - 15.72s - Retrieved new start ID 650912963
# 207 - 15.84s - Retrieved new start ID 654014027
# 208 - 15.86s - Retrieved new start ID 657115286
# 209 - 15.69s - Retrieved new start ID 660215766
# 210 - 15.70s - Retrieved new start ID 663315712
# 211 - 15.90s - Retrieved new start ID 666412448
# 212 - 16.19s - Retrieved new start ID 669498240
# 213 - 14.91s - Retrieved new start ID 672583307
# 214 - 15.82s - Retrieved new start ID 675668471
# 215 - 15.53s - Retrieved new start ID 678753376
# 216 - 15.73s - Retrieved new start ID 681836491
# 217 - 16.68s - Retrieved new start ID 684917323
# 218 - 15.16s - Retrieved new start ID 687997583
# 219 - 15.81s - Retrieved new start ID 691078035
# 220 - 15.67s - Retrieved new start ID 694158662
# 221 - 15.95s - Retrieved new start ID 697238816
# 222 - 15.99s - Retrieved new start ID 700318523
# 223 - 16.11s - Retrieved new start ID 703399040
# 224 - 16.22s - Retrieved new start ID 706479150
# 225 - 16.78s - Retrieved new start ID 709558135
# 226 - 15.32s - Retrieved new start ID 712632568
# 227 - 15.68s - Retrieved new start ID 715707104
# 228 - 16.32s - Retrieved new start ID 718782129
# 229 - 15.32s - Retrieved new start ID 721856671
# 230 - 15.87s - Retrieved new start ID 724931936
# 231 - 15.88s - Retrieved new start ID 728007627
# 232 - 15.85s - Retrieved new start ID 731083662
# 233 - 15.48s - Retrieved new start ID 734159387
# 234 - 16.29s - Retrieved new start ID 737235506
# 235 - 15.21s - Retrieved new start ID 740308240
# 236 - 15.38s - Retrieved new start ID 743381101
# 237 - 15.31s - Retrieved new start ID 746453878
# 238 - 16.13s - Retrieved new start ID 749526613
# 239 - 16.57s - Retrieved new start ID 752598602
# 240 - 15.91s - Retrieved new start ID 755670561
# 241 - 15.37s - Retrieved new start ID 758742485
# 242 - 16.09s - Retrieved new start ID 761814117
# 243 - 15.78s - Retrieved new start ID 764885766
# 244 - 15.61s - Retrieved new start ID 767957077
# 245 - 15.45s - Retrieved new start ID 771128114
# 246 - 15.94s - Retrieved new start ID 774312656
# 247 - 15.94s - Retrieved new start ID 777497070
# 248 - 16.06s - Retrieved new start ID 780682694
# 249 - 15.69s - Retrieved new start ID 783858742
# 250 - 15.17s - Retrieved new start ID 786931666
# 251 - 16.29s - Retrieved new start ID 790004711
# 252 - 15.91s - Retrieved new start ID 793077576
# 253 - 16.38s - Retrieved new start ID 796150614
# 254 - 15.76s - Retrieved new start ID 799220288
# 255 - 15.72s - Retrieved new start ID 802282843
# 256 - 16.02s - Retrieved new start ID 805346808
# 257 - 16.14s - Retrieved new start ID 808409904
# 258 - 17.13s - Retrieved new start ID 811472969
# 259 - 15.57s - Retrieved new start ID 814528263
# 260 - 15.82s - Retrieved new start ID 817582381
# 261 - 16.92s - Retrieved new start ID 820636703
# 262 - 16.60s - Retrieved new start ID 823690579
# 263 - 16.22s - Retrieved new start ID 826741778
# 264 - 15.99s - Retrieved new start ID 829791681
# 265 - 16.13s - Retrieved new start ID 832841640
# 266 - 16.64s - Retrieved new start ID 835891664
# 267 - 16.75s - Retrieved new start ID 838942354
# 268 - 15.50s - Retrieved new start ID 841994619
# 269 - 15.17s - Retrieved new start ID 845046648
# 270 - 15.88s - Retrieved new start ID 848098445
# 271 - 16.19s - Retrieved new start ID 851150411
# 272 - 15.28s - Retrieved new start ID 854207508
# 273 - 15.55s - Retrieved new start ID 857283711
# 274 - 15.19s - Retrieved new start ID 860359563
# 275 - 15.74s - Retrieved new start ID 863435531
# 276 - 16.01s - Retrieved new start ID 866511568
# 277 - 16.77s - Retrieved new start ID 869584395
# 278 - 15.82s - Retrieved new start ID 872653853
# 279 - 15.96s - Retrieved new start ID 875723519
# 280 - 15.99s - Retrieved new start ID 878794011
# 281 - 16.08s - Retrieved new start ID 881863579
# 282 - 15.44s - Retrieved new start ID 884922775
# 283 - 15.54s - Retrieved new start ID 887981945
# 284 - 15.79s - Retrieved new start ID 891041354
# 285 - 16.03s - Retrieved new start ID 894100756
# 286 - 15.77s - Retrieved new start ID 897163129
# 287 - 15.42s - Retrieved new start ID 900228273
# 288 - 17.48s - Retrieved new start ID 903293001
# 289 - 16.22s - Retrieved new start ID 906358656
# 290 - 15.42s - Retrieved new start ID 909424683
# 291 - 15.50s - Retrieved new start ID 912494052
# 292 - 15.63s - Retrieved new start ID 915564115
# 293 - 15.83s - Retrieved new start ID 918633702
# 294 - 15.91s - Retrieved new start ID 921703697
# 295 - 16.74s - Retrieved new start ID 924775589
# 296 - 15.77s - Retrieved new start ID 927858051
# 297 - 15.91s - Retrieved new start ID 930939759
# 298 - 15.80s - Retrieved new start ID 934021539
# 299 - 15.18s - Retrieved new start ID 937102955
# 300 - 17.78s - Retrieved new start ID 940190731
# 301 - 15.80s - Retrieved new start ID 943285812
# 302 - 15.81s - Retrieved new start ID 946381535
# 303 - 16.18s - Retrieved new start ID 949477046
# 304 - 15.55s - Retrieved new start ID 952572539
# 305 - 15.70s - Retrieved new start ID 955673067
# 306 - 15.76s - Retrieved new start ID 958776087
# 307 - 17.05s - Retrieved new start ID 961879124
# 308 - 16.43s - Retrieved new start ID 964981752
# 309 - 16.05s - Retrieved new start ID 968085600
# 310 - 16.50s - Retrieved new start ID 971189467
# 311 - 17.21s - Retrieved new start ID 974294500
# 312 - 15.46s - Retrieved new start ID 977398603
# 313 - 15.08s - Retrieved new start ID 980503153
# 372 - 16.19s - Retrieved new start ID 1161862518
# 373 - 15.63s - Retrieved new start ID 1164928276
# 374 - 15.78s - Retrieved new start ID 1167994449
# 375 - 16.26s - Retrieved new start ID 1171061506
# 376 - 15.54s - Retrieved new start ID 1174132066
# 377 - 16.24s - Retrieved new start ID 1177203238
# 378 - 16.00s - Retrieved new start ID 1180273753
# 379 - 15.42s - Retrieved new start ID 1183343548
# 380 - 15.44s - Retrieved new start ID 1186412213
# 381 - 16.10s - Retrieved new start ID 1189480885
# 382 - 15.83s - Retrieved new start ID 1192549527
# 383 - 4.60s - Retrieved new start ID 1193123824
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-a8c2bb2ba887> in <module>
#      13         if last_line == "":
#      14             break
# ---> 15         index = int(last_line.split(",")[0])
#      16         # Compress the file
#      17         os.popen('gzip -f %s' % (fn))
#
# ValueError: invalid literal for int() with base 10: 'id'

# %% [markdown]
# # Preprocessing and Analysis
#
# ### Changing the file format
# The data is in zipped csv files that are super slow to load.
# We convert it to a single h5py dataset, compressed, with the following keys:
#  - X : the data matrix
#  - Y : the targets

# %%
import numpy
import torch
import pandas as pd
import h5py
import time
import os
import numpy as np

# %%
data_folder = "/data/DATASETS/NYCTAXI/PROCESSED/"
def list_files(folder):
    for r, d, f in os.walk(folder):
        for file in f:
            if file.endswith('.csv.gz'):
                yield os.path.join(r, file)

# %% [markdown]
# First we read the data in memory, and place it into a separate numpy array per each file

# %%
all_x = []
all_y = []
for f in list_files(data_folder):
    t_s = time.time()
    df = pd.read_csv(f, header=0, index_col=False)
    Y = df['duration'].to_numpy(np.int32, copy=True)
    X = df[['time', 'dow', 'dom', 'month', 'round',
            'round.1', 'round.2', 'round.3',
            'round.4']].to_numpy(np.float64, copy=True)
    all_x.append(X)
    all_y.append(Y)
    del df
    print("file %s read in %.2fs" % (f, time.time() - t_s))
# Out:
# file /data/DATASETS/NYCTAXI/PROCESSED/1066724750.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/616730994.csv.gz read in 4.70s
# file /data/DATASETS/NYCTAXI/PROCESSED/700318523.csv.gz read in 4.59s
# file /data/DATASETS/NYCTAXI/PROCESSED/294064714.csv.gz read in 4.72s
# file /data/DATASETS/NYCTAXI/PROCESSED/1002169437.csv.gz read in 4.76s
# file /data/DATASETS/NYCTAXI/PROCESSED/359154558.csv.gz read in 4.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/340566875.csv.gz read in 4.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/1014456771.csv.gz read in 4.75s
# file /data/DATASETS/NYCTAXI/PROCESSED/755670561.csv.gz read in 4.59s
# file /data/DATASETS/NYCTAXI/PROCESSED/105750702.csv.gz read in 4.82s
# file /data/DATASETS/NYCTAXI/PROCESSED/38193871.csv.gz read in 4.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/349859862.csv.gz read in 4.70s
# file /data/DATASETS/NYCTAXI/PROCESSED/207237975.csv.gz read in 4.72s
# file /data/DATASETS/NYCTAXI/PROCESSED/996008571.csv.gz read in 4.60s
# file /data/DATASETS/NYCTAXI/PROCESSED/238176360.csv.gz read in 5.20s
# file /data/DATASETS/NYCTAXI/PROCESSED/802282843.csv.gz read in 4.70s
# file /data/DATASETS/NYCTAXI/PROCESSED/219587287.csv.gz read in 4.82s
# file /data/DATASETS/NYCTAXI/PROCESSED/244380372.csv.gz read in 4.78s
# file /data/DATASETS/NYCTAXI/PROCESSED/312672455.csv.gz read in 4.81s
# file /data/DATASETS/NYCTAXI/PROCESSED/897163129.csv.gz read in 4.67s
# file /data/DATASETS/NYCTAXI/PROCESSED/47418586.csv.gz read in 4.75s
# file /data/DATASETS/NYCTAXI/PROCESSED/663315712.csv.gz read in 4.67s
# file /data/DATASETS/NYCTAXI/PROCESSED/59710543.csv.gz read in 4.77s
# file /data/DATASETS/NYCTAXI/PROCESSED/989820864.csv.gz read in 4.89s
# file /data/DATASETS/NYCTAXI/PROCESSED/832841640.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/161004334.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/891041354.csv.gz read in 4.87s
# file /data/DATASETS/NYCTAXI/PROCESSED/619836262.csv.gz read in 4.91s
# file /data/DATASETS/NYCTAXI/PROCESSED/613626317.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/660215766.csv.gz read in 4.78s
# file /data/DATASETS/NYCTAXI/PROCESSED/489640517.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/622941789.csv.gz read in 4.88s
# file /data/DATASETS/NYCTAXI/PROCESSED/1122027125.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/900228273.csv.gz read in 4.85s
# file /data/DATASETS/NYCTAXI/PROCESSED/1186412213.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/940190731.csv.gz read in 4.84s
# file /data/DATASETS/NYCTAXI/PROCESSED/1075964947.csv.gz read in 5.05s
# file /data/DATASETS/NYCTAXI/PROCESSED/687997583.csv.gz read in 5.44s
# file /data/DATASETS/NYCTAXI/PROCESSED/918633702.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/439945695.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/19614671.csv.gz read in 4.91s
# file /data/DATASETS/NYCTAXI/PROCESSED/937102955.csv.gz read in 4.88s
# file /data/DATASETS/NYCTAXI/PROCESSED/694158662.csv.gz read in 4.90s
# file /data/DATASETS/NYCTAXI/PROCESSED/337466685.csv.gz read in 5.80s
# file /data/DATASETS/NYCTAXI/PROCESSED/564002866.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/374714973.csv.gz read in 4.87s
# file /data/DATASETS/NYCTAXI/PROCESSED/644693261.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/284731810.csv.gz read in 5.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/53561398.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/498943605.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/517528214.csv.gz read in 5.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/0.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/247482398.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/783858742.csv.gz read in 4.98s
# file /data/DATASETS/NYCTAXI/PROCESSED/638473572.csv.gz read in 4.98s
# file /data/DATASETS/NYCTAXI/PROCESSED/1109761923.csv.gz read in 5.30s
# file /data/DATASETS/NYCTAXI/PROCESSED/1146538549.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/306473086.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/1174132066.csv.gz read in 5.43s
# file /data/DATASETS/NYCTAXI/PROCESSED/579494476.csv.gz read in 5.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/869584395.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/952572539.csv.gz read in 5.01s
# file /data/DATASETS/NYCTAXI/PROCESSED/1100556542.csv.gz read in 5.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/1008323191.csv.gz read in 5.15s
# file /data/DATASETS/NYCTAXI/PROCESSED/678753376.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/1032878394.csv.gz read in 5.13s
# file /data/DATASETS/NYCTAXI/PROCESSED/231975502.csv.gz read in 4.98s
# file /data/DATASETS/NYCTAXI/PROCESSED/182577289.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/300271790.csv.gz read in 5.04s
# file /data/DATASETS/NYCTAXI/PROCESSED/999089116.csv.gz read in 5.18s
# file /data/DATASETS/NYCTAXI/PROCESSED/446132141.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/430679071.csv.gz read in 6.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/1106693976.csv.gz read in 5.18s
# file /data/DATASETS/NYCTAXI/PROCESSED/235076098.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/259892086.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/170255350.csv.gz read in 5.24s
# file /data/DATASETS/NYCTAXI/PROCESSED/793077576.csv.gz read in 5.21s
# file /data/DATASETS/NYCTAXI/PROCESSED/213409331.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/62785891.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/1088272650.csv.gz read in 5.21s
# file /data/DATASETS/NYCTAXI/PROCESSED/102688619.csv.gz read in 5.19s
# file /data/DATASETS/NYCTAXI/PROCESSED/548506760.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/675668471.csv.gz read in 5.01s
# file /data/DATASETS/NYCTAXI/PROCESSED/256789322.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/1171061506.csv.gz read in 5.13s
# file /data/DATASETS/NYCTAXI/PROCESSED/848098445.csv.gz read in 4.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/84320521.csv.gz read in 5.32s
# file /data/DATASETS/NYCTAXI/PROCESSED/912494052.csv.gz read in 5.01s
# file /data/DATASETS/NYCTAXI/PROCESSED/1017523846.csv.gz read in 5.17s
# file /data/DATASETS/NYCTAXI/PROCESSED/790004711.csv.gz read in 4.96s
# file /data/DATASETS/NYCTAXI/PROCESSED/1097487252.csv.gz read in 5.21s
# file /data/DATASETS/NYCTAXI/PROCESSED/761814117.csv.gz read in 4.85s
# file /data/DATASETS/NYCTAXI/PROCESSED/41275223.csv.gz read in 4.98s
# file /data/DATASETS/NYCTAXI/PROCESSED/495842223.csv.gz read in 6.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/371589474.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/1069805634.csv.gz read in 6.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/424495727.csv.gz read in 4.91s
# file /data/DATASETS/NYCTAXI/PROCESSED/585692011.csv.gz read in 4.97s
# file /data/DATASETS/NYCTAXI/PROCESSED/108811935.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/197989435.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/860359563.csv.gz read in 4.90s
# file /data/DATASETS/NYCTAXI/PROCESSED/127202340.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/16500092.csv.gz read in 5.01s
# file /data/DATASETS/NYCTAXI/PROCESSED/949477046.csv.gz read in 5.44s
# file /data/DATASETS/NYCTAXI/PROCESSED/90443290.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/854207508.csv.gz read in 4.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/1026734599.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/22730160.csv.gz read in 5.05s
# file /data/DATASETS/NYCTAXI/PROCESSED/986715202.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/114938154.csv.gz read in 5.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/887981945.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/50489809.csv.gz read in 4.97s
# file /data/DATASETS/NYCTAXI/PROCESSED/598099417.csv.gz read in 4.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/262994002.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/157920592.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/250584488.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/412115009.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/464739381.csv.gz read in 5.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/1023662625.csv.gz read in 5.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/1137347802.csv.gz read in 5.06s
# file /data/DATASETS/NYCTAXI/PROCESSED/418305284.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/1115895600.csv.gz read in 5.05s
# file /data/DATASETS/NYCTAXI/PROCESSED/176415963.csv.gz read in 5.10s
# file /data/DATASETS/NYCTAXI/PROCESSED/216498298.csv.gz read in 4.96s
# file /data/DATASETS/NYCTAXI/PROCESSED/225774499.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/647802973.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/222676062.csv.gz read in 5.34s
# file /data/DATASETS/NYCTAXI/PROCESSED/290953966.csv.gz read in 4.97s
# file /data/DATASETS/NYCTAXI/PROCESSED/983609483.csv.gz read in 5.01s
# file /data/DATASETS/NYCTAXI/PROCESSED/632259696.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/325060094.csv.gz read in 5.06s
# file /data/DATASETS/NYCTAXI/PROCESSED/28944407.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/281623287.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/588790539.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/964981752.csv.gz read in 4.90s
# file /data/DATASETS/NYCTAXI/PROCESSED/841994619.csv.gz read in 5.29s
# file /data/DATASETS/NYCTAXI/PROCESSED/567101460.csv.gz read in 4.91s
# file /data/DATASETS/NYCTAXI/PROCESSED/1054405743.csv.gz read in 5.32s
# file /data/DATASETS/NYCTAXI/PROCESSED/96565501.csv.gz read in 5.15s
# file /data/DATASETS/NYCTAXI/PROCESSED/838942354.csv.gz read in 4.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/666412448.csv.gz read in 5.05s
# file /data/DATASETS/NYCTAXI/PROCESSED/1125092153.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/672583307.csv.gz read in 4.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/629153169.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/483430072.csv.gz read in 5.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/328160895.csv.gz read in 5.22s
# file /data/DATASETS/NYCTAXI/PROCESSED/142548202.csv.gz read in 5.21s
# file /data/DATASETS/NYCTAXI/PROCESSED/508235866.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/297170881.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/650912963.csv.gz read in 4.88s
# file /data/DATASETS/NYCTAXI/PROCESSED/56634818.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/529921670.csv.gz read in 5.27s
# file /data/DATASETS/NYCTAXI/PROCESSED/884922775.csv.gz read in 4.96s
# file /data/DATASETS/NYCTAXI/PROCESSED/133339529.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/1177203238.csv.gz read in 5.50s
# file /data/DATASETS/NYCTAXI/PROCESSED/1140411152.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/872653853.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/808409904.csv.gz read in 4.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/467849789.csv.gz read in 5.38s
# file /data/DATASETS/NYCTAXI/PROCESSED/712632568.csv.gz read in 5.22s
# file /data/DATASETS/NYCTAXI/PROCESSED/968085600.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/691078035.csv.gz read in 5.23s
# file /data/DATASETS/NYCTAXI/PROCESSED/287842671.csv.gz read in 5.18s
# file /data/DATASETS/NYCTAXI/PROCESSED/1082121418.csv.gz read in 5.26s
# file /data/DATASETS/NYCTAXI/PROCESSED/1103625009.csv.gz read in 5.55s
# file /data/DATASETS/NYCTAXI/PROCESSED/384089159.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/1005250611.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/545407332.csv.gz read in 4.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/136407795.csv.gz read in 5.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/436856640.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/974294500.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/455418561.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/523725471.csv.gz read in 5.06s
# file /data/DATASETS/NYCTAXI/PROCESSED/1072886644.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/111873519.csv.gz read in 5.14s
# file /data/DATASETS/NYCTAXI/PROCESSED/1180273753.csv.gz read in 5.37s
# file /data/DATASETS/NYCTAXI/PROCESSED/362252174.csv.gz read in 5.04s
# file /data/DATASETS/NYCTAXI/PROCESSED/151766239.csv.gz read in 5.21s
# file /data/DATASETS/NYCTAXI/PROCESSED/346762841.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/1035951791.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/390333243.csv.gz read in 4.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/758742485.csv.gz read in 5.02s
# file /data/DATASETS/NYCTAXI/PROCESSED/269200049.csv.gz read in 4.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/654014027.csv.gz read in 4.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/943285812.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/173335433.csv.gz read in 5.17s
# file /data/DATASETS/NYCTAXI/PROCESSED/87381840.csv.gz read in 5.33s
# file /data/DATASETS/NYCTAXI/PROCESSED/607414761.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/1128155997.csv.gz read in 6.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/228874659.csv.gz read in 5.05s
# file /data/DATASETS/NYCTAXI/PROCESSED/906358656.csv.gz read in 4.96s
# file /data/DATASETS/NYCTAXI/PROCESSED/829791681.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/805346808.csv.gz read in 4.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/1057484496.csv.gz read in 5.28s
# file /data/DATASETS/NYCTAXI/PROCESSED/554706500.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/715707104.csv.gz read in 4.94s
# file /data/DATASETS/NYCTAXI/PROCESSED/405901208.csv.gz read in 4.96s
# file /data/DATASETS/NYCTAXI/PROCESSED/148693648.csv.gz read in 5.13s
# file /data/DATASETS/NYCTAXI/PROCESSED/1063643821.csv.gz read in 5.21s
# file /data/DATASETS/NYCTAXI/PROCESSED/915564115.csv.gz read in 5.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/780682694.csv.gz read in 5.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/1161862518.csv.gz read in 5.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/121070002.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/194906670.csv.gz read in 5.09s
# file /data/DATASETS/NYCTAXI/PROCESSED/1094415113.csv.gz read in 5.19s
# file /data/DATASETS/NYCTAXI/PROCESSED/771128114.csv.gz read in 4.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/272305660.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/164087980.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/449227749.csv.gz read in 5.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/526823762.csv.gz read in 5.00s
# file /data/DATASETS/NYCTAXI/PROCESSED/35110928.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/826741778.csv.gz read in 5.74s
# file /data/DATASETS/NYCTAXI/PROCESSED/1167994449.csv.gz read in 5.14s
# file /data/DATASETS/NYCTAXI/PROCESSED/1189480885.csv.gz read in 5.11s
# file /data/DATASETS/NYCTAXI/PROCESSED/958776087.csv.gz read in 4.97s
# file /data/DATASETS/NYCTAXI/PROCESSED/505139460.csv.gz read in 5.42s
# file /data/DATASETS/NYCTAXI/PROCESSED/582593228.csv.gz read in 5.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/275411038.csv.gz read in 5.62s
# file /data/DATASETS/NYCTAXI/PROCESSED/1143474953.csv.gz read in 5.57s
# file /data/DATASETS/NYCTAXI/PROCESSED/594994528.csv.gz read in 5.51s
# file /data/DATASETS/NYCTAXI/PROCESSED/1020591224.csv.gz read in 5.67s
# file /data/DATASETS/NYCTAXI/PROCESSED/875723519.csv.gz read in 5.53s
# file /data/DATASETS/NYCTAXI/PROCESSED/641583475.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/1048249110.csv.gz read in 5.78s
# file /data/DATASETS/NYCTAXI/PROCESSED/1051327268.csv.gz read in 5.69s
# file /data/DATASETS/NYCTAXI/PROCESSED/365350815.csv.gz read in 5.58s
# file /data/DATASETS/NYCTAXI/PROCESSED/480312075.csv.gz read in 5.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/927858051.csv.gz read in 5.54s
# file /data/DATASETS/NYCTAXI/PROCESSED/811472969.csv.gz read in 5.45s
# file /data/DATASETS/NYCTAXI/PROCESSED/737235506.csv.gz read in 5.44s
# file /data/DATASETS/NYCTAXI/PROCESSED/835891664.csv.gz read in 5.40s
# file /data/DATASETS/NYCTAXI/PROCESSED/318866797.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/1091344207.csv.gz read in 5.73s
# file /data/DATASETS/NYCTAXI/PROCESSED/25844686.csv.gz read in 5.39s
# file /data/DATASETS/NYCTAXI/PROCESSED/118004166.csv.gz read in 5.58s
# file /data/DATASETS/NYCTAXI/PROCESSED/201072105.csv.gz read in 5.38s
# file /data/DATASETS/NYCTAXI/PROCESSED/477194714.csv.gz read in 5.55s
# file /data/DATASETS/NYCTAXI/PROCESSED/669498240.csv.gz read in 5.40s
# file /data/DATASETS/NYCTAXI/PROCESSED/734159387.csv.gz read in 5.44s
# file /data/DATASETS/NYCTAXI/PROCESSED/1152666907.csv.gz read in 5.48s
# file /data/DATASETS/NYCTAXI/PROCESSED/393455014.csv.gz read in 5.43s
# file /data/DATASETS/NYCTAXI/PROCESSED/1029806272.csv.gz read in 5.41s
# file /data/DATASETS/NYCTAXI/PROCESSED/377841012.csv.gz read in 5.32s
# file /data/DATASETS/NYCTAXI/PROCESSED/415210256.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/427590064.csv.gz read in 5.40s
# file /data/DATASETS/NYCTAXI/PROCESSED/145620755.csv.gz read in 5.54s
# file /data/DATASETS/NYCTAXI/PROCESSED/961879124.csv.gz read in 5.35s
# file /data/DATASETS/NYCTAXI/PROCESSED/573298160.csv.gz read in 5.49s
# file /data/DATASETS/NYCTAXI/PROCESSED/1192549527.csv.gz read in 0.95s
# file /data/DATASETS/NYCTAXI/PROCESSED/681836491.csv.gz read in 5.49s
# file /data/DATASETS/NYCTAXI/PROCESSED/387211204.csv.gz read in 5.38s
# file /data/DATASETS/NYCTAXI/PROCESSED/68936775.csv.gz read in 5.43s
# file /data/DATASETS/NYCTAXI/PROCESSED/343664962.csv.gz read in 5.52s
# file /data/DATASETS/NYCTAXI/PROCESSED/570200007.csv.gz read in 5.49s
# file /data/DATASETS/NYCTAXI/PROCESSED/1134284289.csv.gz read in 5.47s
# file /data/DATASETS/NYCTAXI/PROCESSED/817582381.csv.gz read in 5.26s
# file /data/DATASETS/NYCTAXI/PROCESSED/32027576.csv.gz read in 5.42s
# file /data/DATASETS/NYCTAXI/PROCESSED/934021539.csv.gz read in 5.25s
# file /data/DATASETS/NYCTAXI/PROCESSED/130270874.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/823690579.csv.gz read in 6.03s
# file /data/DATASETS/NYCTAXI/PROCESSED/191823654.csv.gz read in 6.44s
# file /data/DATASETS/NYCTAXI/PROCESSED/857283711.csv.gz read in 5.38s
# file /data/DATASETS/NYCTAXI/PROCESSED/78167466.csv.gz read in 5.50s
# file /data/DATASETS/NYCTAXI/PROCESSED/820636703.csv.gz read in 5.37s
# file /data/DATASETS/NYCTAXI/PROCESSED/851150411.csv.gz read in 5.45s
# file /data/DATASETS/NYCTAXI/PROCESSED/179496509.csv.gz read in 5.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/75090936.csv.gz read in 5.71s
# file /data/DATASETS/NYCTAXI/PROCESSED/1042099975.csv.gz read in 5.55s
# file /data/DATASETS/NYCTAXI/PROCESSED/368464133.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/352957495.csv.gz read in 5.55s
# file /data/DATASETS/NYCTAXI/PROCESSED/799220288.csv.gz read in 5.44s
# file /data/DATASETS/NYCTAXI/PROCESSED/402793262.csv.gz read in 5.62s
# file /data/DATASETS/NYCTAXI/PROCESSED/764885766.csv.gz read in 5.63s
# file /data/DATASETS/NYCTAXI/PROCESSED/321963484.csv.gz read in 5.78s
# file /data/DATASETS/NYCTAXI/PROCESSED/253686819.csv.gz read in 5.58s
# file /data/DATASETS/NYCTAXI/PROCESSED/1011389892.csv.gz read in 5.64s
# file /data/DATASETS/NYCTAXI/PROCESSED/210320485.csv.gz read in 5.53s
# file /data/DATASETS/NYCTAXI/PROCESSED/1131220057.csv.gz read in 5.60s
# file /data/DATASETS/NYCTAXI/PROCESSED/1164928276.csv.gz read in 5.70s
# file /data/DATASETS/NYCTAXI/PROCESSED/99626891.csv.gz read in 5.51s
# file /data/DATASETS/NYCTAXI/PROCESSED/334365082.csv.gz read in 5.60s
# file /data/DATASETS/NYCTAXI/PROCESSED/278517765.csv.gz read in 5.60s
# file /data/DATASETS/NYCTAXI/PROCESSED/461629493.csv.gz read in 5.46s
# file /data/DATASETS/NYCTAXI/PROCESSED/452322840.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/591889373.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/551606563.csv.gz read in 5.59s
# file /data/DATASETS/NYCTAXI/PROCESSED/845046648.csv.gz read in 5.72s
# file /data/DATASETS/NYCTAXI/PROCESSED/718782129.csv.gz read in 5.58s
# file /data/DATASETS/NYCTAXI/PROCESSED/315770025.csv.gz read in 5.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/1149602720.csv.gz read in 6.62s
# file /data/DATASETS/NYCTAXI/PROCESSED/241278097.csv.gz read in 5.92s
# file /data/DATASETS/NYCTAXI/PROCESSED/746453878.csv.gz read in 5.50s
# file /data/DATASETS/NYCTAXI/PROCESSED/396576627.csv.gz read in 5.89s
# file /data/DATASETS/NYCTAXI/PROCESSED/977398603.csv.gz read in 5.48s
# file /data/DATASETS/NYCTAXI/PROCESSED/878794011.csv.gz read in 5.59s
# file /data/DATASETS/NYCTAXI/PROCESSED/752598602.csv.gz read in 5.45s
# file /data/DATASETS/NYCTAXI/PROCESSED/728007627.csv.gz read in 8.07s
# file /data/DATASETS/NYCTAXI/PROCESSED/767957077.csv.gz read in 9.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/520626802.csv.gz read in 10.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/740308240.csv.gz read in 9.41s
# file /data/DATASETS/NYCTAXI/PROCESSED/749526613.csv.gz read in 9.51s
# file /data/DATASETS/NYCTAXI/PROCESSED/514430094.csv.gz read in 9.90s
# file /data/DATASETS/NYCTAXI/PROCESSED/72013909.csv.gz read in 9.63s
# file /data/DATASETS/NYCTAXI/PROCESSED/921703697.csv.gz read in 9.64s
# file /data/DATASETS/NYCTAXI/PROCESSED/909424683.csv.gz read in 9.85s
# file /data/DATASETS/NYCTAXI/PROCESSED/1060563561.csv.gz read in 9.83s
# file /data/DATASETS/NYCTAXI/PROCESSED/331262752.csv.gz read in 10.52s
# file /data/DATASETS/NYCTAXI/PROCESSED/721856671.csv.gz read in 10.16s
# file /data/DATASETS/NYCTAXI/PROCESSED/626047453.csv.gz read in 9.78s
# file /data/DATASETS/NYCTAXI/PROCESSED/421400016.csv.gz read in 9.12s
# file /data/DATASETS/NYCTAXI/PROCESSED/139475800.csv.gz read in 8.47s
# file /data/DATASETS/NYCTAXI/PROCESSED/980503153.csv.gz read in 7.39s
# file /data/DATASETS/NYCTAXI/PROCESSED/536116450.csv.gz read in 10.06s
# file /data/DATASETS/NYCTAXI/PROCESSED/557806295.csv.gz read in 9.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/309573509.csv.gz read in 4.99s
# file /data/DATASETS/NYCTAXI/PROCESSED/266097072.csv.gz read in 6.97s
# file /data/DATASETS/NYCTAXI/PROCESSED/65861415.csv.gz read in 5.56s
# file /data/DATASETS/NYCTAXI/PROCESSED/93504224.csv.gz read in 5.59s
# file /data/DATASETS/NYCTAXI/PROCESSED/709558135.csv.gz read in 5.64s
# file /data/DATASETS/NYCTAXI/PROCESSED/796150614.csv.gz read in 5.51s
# file /data/DATASETS/NYCTAXI/PROCESSED/774312656.csv.gz read in 5.42s
# file /data/DATASETS/NYCTAXI/PROCESSED/881863579.csv.gz read in 5.45s
# file /data/DATASETS/NYCTAXI/PROCESSED/814528263.csv.gz read in 5.37s
# file /data/DATASETS/NYCTAXI/PROCESSED/433767535.csv.gz read in 5.47s
# file /data/DATASETS/NYCTAXI/PROCESSED/684917323.csv.gz read in 5.47s
# file /data/DATASETS/NYCTAXI/PROCESSED/124135478.csv.gz read in 5.54s
# file /data/DATASETS/NYCTAXI/PROCESSED/604309650.csv.gz read in 5.63s
# file /data/DATASETS/NYCTAXI/PROCESSED/1045173530.csv.gz read in 5.57s
# file /data/DATASETS/NYCTAXI/PROCESSED/167171785.csv.gz read in 5.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/703399040.csv.gz read in 5.50s
# file /data/DATASETS/NYCTAXI/PROCESSED/576396154.csv.gz read in 5.45s
# file /data/DATASETS/NYCTAXI/PROCESSED/863435531.csv.gz read in 5.52s
# file /data/DATASETS/NYCTAXI/PROCESSED/399686170.csv.gz read in 5.43s
# file /data/DATASETS/NYCTAXI/PROCESSED/486539367.csv.gz read in 5.68s
# file /data/DATASETS/NYCTAXI/PROCESSED/930939759.csv.gz read in 5.43s
# file /data/DATASETS/NYCTAXI/PROCESSED/1183343548.csv.gz read in 5.54s
# file /data/DATASETS/NYCTAXI/PROCESSED/1155731139.csv.gz read in 5.64s
# file /data/DATASETS/NYCTAXI/PROCESSED/474077780.csv.gz read in 5.50s
# file /data/DATASETS/NYCTAXI/PROCESSED/697238816.csv.gz read in 5.47s
# file /data/DATASETS/NYCTAXI/PROCESSED/946381535.csv.gz read in 5.62s
# file /data/DATASETS/NYCTAXI/PROCESSED/1118961265.csv.gz read in 5.64s
# file /data/DATASETS/NYCTAXI/PROCESSED/1085199930.csv.gz read in 5.68s
# file /data/DATASETS/NYCTAXI/PROCESSED/44347304.csv.gz read in 5.55s
# file /data/DATASETS/NYCTAXI/PROCESSED/601204396.csv.gz read in 5.52s
# file /data/DATASETS/NYCTAXI/PROCESSED/188741177.csv.gz read in 5.66s
# file /data/DATASETS/NYCTAXI/PROCESSED/992926307.csv.gz read in 5.39s
# file /data/DATASETS/NYCTAXI/PROCESSED/303372020.csv.gz read in 5.64s
# file /data/DATASETS/NYCTAXI/PROCESSED/154838358.csv.gz read in 7.72s
# file /data/DATASETS/NYCTAXI/PROCESSED/777497070.csv.gz read in 10.06s
# file /data/DATASETS/NYCTAXI/PROCESSED/1158795791.csv.gz read in 10.31s
# file /data/DATASETS/NYCTAXI/PROCESSED/470960813.csv.gz read in 10.20s
# file /data/DATASETS/NYCTAXI/PROCESSED/971189467.csv.gz read in 10.37s
# file /data/DATASETS/NYCTAXI/PROCESSED/724931936.csv.gz read in 10.18s
# file /data/DATASETS/NYCTAXI/PROCESSED/356055660.csv.gz read in 7.22s
# file /data/DATASETS/NYCTAXI/PROCESSED/786931666.csv.gz read in 7.08s
# file /data/DATASETS/NYCTAXI/PROCESSED/492741445.csv.gz read in 10.33s
# file /data/DATASETS/NYCTAXI/PROCESSED/610520601.csv.gz read in 10.15s
# file /data/DATASETS/NYCTAXI/PROCESSED/955673067.csv.gz read in 10.10s
# file /data/DATASETS/NYCTAXI/PROCESSED/380967304.csv.gz read in 10.53s
# file /data/DATASETS/NYCTAXI/PROCESSED/657115286.csv.gz read in 10.72s
# file /data/DATASETS/NYCTAXI/PROCESSED/533018786.csv.gz read in 11.30s
# file /data/DATASETS/NYCTAXI/PROCESSED/502042875.csv.gz read in 6.90s
# file /data/DATASETS/NYCTAXI/PROCESSED/1039025821.csv.gz read in 10.47s
# file /data/DATASETS/NYCTAXI/PROCESSED/560905635.csv.gz read in 10.19s
# file /data/DATASETS/NYCTAXI/PROCESSED/539213615.csv.gz read in 10.27s
# file /data/DATASETS/NYCTAXI/PROCESSED/903293001.csv.gz read in 5.35s
# file /data/DATASETS/NYCTAXI/PROCESSED/1112830058.csv.gz read in 5.62s
# file /data/DATASETS/NYCTAXI/PROCESSED/706479150.csv.gz read in 5.28s
# file /data/DATASETS/NYCTAXI/PROCESSED/542310012.csv.gz read in 5.31s
# file /data/DATASETS/NYCTAXI/PROCESSED/458519885.csv.gz read in 4.98s
# file /data/DATASETS/NYCTAXI/PROCESSED/443035983.csv.gz read in 4.93s
# file /data/DATASETS/NYCTAXI/PROCESSED/204154862.csv.gz read in 4.75s
# file /data/DATASETS/NYCTAXI/PROCESSED/185658696.csv.gz read in 5.69s
# file /data/DATASETS/NYCTAXI/PROCESSED/81244284.csv.gz read in 4.75s
# file /data/DATASETS/NYCTAXI/PROCESSED/894100756.csv.gz read in 5.55s
# file /data/DATASETS/NYCTAXI/PROCESSED/635365324.csv.gz read in 5.75s
# file /data/DATASETS/NYCTAXI/PROCESSED/731083662.csv.gz read in 4.84s
# file /data/DATASETS/NYCTAXI/PROCESSED/409008812.csv.gz read in 4.91s
# file /data/DATASETS/NYCTAXI/PROCESSED/1079043488.csv.gz read in 4.90s
# file /data/DATASETS/NYCTAXI/PROCESSED/866511568.csv.gz read in 4.88s
# file /data/DATASETS/NYCTAXI/PROCESSED/924775589.csv.gz read in 7.51s
# file /data/DATASETS/NYCTAXI/PROCESSED/743381101.csv.gz read in 5.67s
# file /data/DATASETS/NYCTAXI/PROCESSED/511332969.csv.gz read in 4.96s

# %%
num_samples = sum([arr.shape[0] for arr in all_x])
dim = all_x[0].shape[1]
print(num_samples, ",", dim)
# Out:
# 1146561612 , 9

# %%
max_chunk_size = 2 * 2**20  # 2MB
chunk_x = int(max_chunk_size / dim / 8)
chunk_y = chunk_x
print("Chunk size:", chunk_x)
# Out:
# Chunk size: 29127

# %%
with h5py.File(os.path.join(data_folder, 'full.h5py'), 'w', libver='latest') as f:
    Xdset = f.create_dataset("X", (num_samples, dim), dtype='float64', 
                             compression="gzip", chunks=(chunk_x, dim))
    Ydset = f.create_dataset("Y", (num_samples, 1), dtype='int32')
    current_i = 0
    for X, Y in zip(all_x, all_y):
        t_s = time.time()
        X = np.ascontiguousarray(X)
        Y = Y.reshape((-1, 1))
        Xdset.write_direct(X, dest_sel=np.s_[current_i:current_i+X.shape[0], :])
        Ydset.write_direct(Y, dest_sel=np.s_[current_i:current_i+Y.shape[0], :])
        current_i += X.shape[0]
        print("i: %d/%d in %.2fs" % (current_i, num_samples, time.time() - t_s))
# Out:
# i: 3000000/1146561612 in 7.86s
# i: 6000000/1146561612 in 9.08s
# i: 9000000/1146561612 in 7.69s
# i: 12000000/1146561612 in 7.96s
# i: 15000000/1146561612 in 8.49s
# i: 18000000/1146561612 in 8.30s
# i: 21000000/1146561612 in 9.39s
# i: 24000000/1146561612 in 8.55s
